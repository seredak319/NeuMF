# %%
import datetime
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from scipy import sparse
from typing import List

# %%
print(f"Tensorflow version: {tf.__version__}")
print(f"Pandas version: {pd.__version__}")
print(f"Numpy version: {np.__version__}")
# Out:
# Tensorflow version: 2.10.0
# Pandas version: 2.0.3
# Numpy version: 1.23.5

# %%
ratings = pd.read_csv('data/full_ratings.csv', low_memory=False)
print("Wgrano dane do pamięci")
# Out:
# Wgrano dane do pamięci

# %%
ratings
# Out:
#         userId  movieId  rating
# 0            0        0       1
# 1            0        1       1
# 2            0        2       1
# 3            0        3       1
# 4            0        4       0
# ...        ...      ...     ...
# 534782     670      792       0
# 534783     670      793       0
# 534784     670      794       0
# 534785     670      795       0
# 534786     670      796       0
#
# [534787 rows x 3 columns]

# %%
n_users = len(ratings['userId'].unique())
n_items = len(ratings['movieId'].unique())
print("number of unique users: ", n_users)
print("number of unique items: ", n_items)
# Out:
# number of unique users:  671
# number of unique items:  797

# %% [markdown]
# # The model (Neural Collaborative Filtering)
#
# <center><img src="https://raw.githubusercontent.com/murilo-cunha/inteligencia-superficial/master/images/2020-09-11-neural_collaborative_filter/ncf_all_with_alpha.png" width="70%" url="https://developers.google.com/machine-learning/recommendation/collaborative/basics" description="Fonte: https://developers.google.com/machine-learning/recommendation/collaborative/basics" /> </center>

# %%
import tensorflow.keras as keras
from tensorflow.keras.layers import (
    Concatenate,
    Dense,
    Embedding,
    Flatten,
    Input,
    Multiply,
)
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2


def create_ncf_movies(
    number_of_users: int,
    number_of_items: int,
    latent_dim_mf: int = 4,
    latent_dim_mlp: int = 16,
    reg_mf: int = 0,
    reg_mlp: int = 0.01,
    dense_layers: List[int] = [16, 4],
    reg_layers: List[int] = [0.01, 0.01],
    activation_dense: str = "relu",
) -> keras.Model:

    # input layer
    user = Input(shape=(), dtype="int64", name="userId")
    item = Input(shape=(), dtype="int64", name="movieId")

    # embedding layers
    mf_user_embedding = Embedding(
        input_dim=number_of_users,
        output_dim=latent_dim_mf,
        name="mf_user_embedding",
        embeddings_initializer="RandomNormal",
        embeddings_regularizer=l2(reg_mf),
    )
    mf_item_embedding = Embedding(
        input_dim=number_of_items,
        output_dim=latent_dim_mf,
        name="mf_item_embedding",
        embeddings_initializer="RandomNormal",
        embeddings_regularizer=l2(reg_mf),
    )

    mlp_user_embedding = Embedding(
        input_dim=number_of_users,
        output_dim=latent_dim_mlp,
        name="mlp_user_embedding",
        embeddings_initializer="RandomNormal",
        embeddings_regularizer=l2(reg_mlp),
    )
    mlp_item_embedding = Embedding(
        input_dim=number_of_items,
        output_dim=latent_dim_mlp,
        name="mlp_item_embedding",
        embeddings_initializer="RandomNormal",
        embeddings_regularizer=l2(reg_mlp),
    )

    # MF vector
    mf_user_latent = Flatten()(mf_user_embedding(user))
    mf_item_latent = Flatten()(mf_item_embedding(item))
    mf_cat_latent = Multiply()([mf_user_latent, mf_item_latent])

    # MLP vector
    mlp_user_latent = Flatten()(mlp_user_embedding(user))
    mlp_item_latent = Flatten()(mlp_item_embedding(item))
    mlp_cat_latent = Concatenate()([mlp_user_latent, mlp_item_latent])

    mlp_vector = mlp_cat_latent

    # build dense layers for model
    for i in range(len(dense_layers)):
        layer = Dense(
            dense_layers[i],
            activity_regularizer=l2(reg_layers[i]),
            activation=activation_dense,
            name="layer%d" % i,
        )
        mlp_vector = layer(mlp_vector)

    predict_layer = Concatenate()([mf_cat_latent, mlp_vector])

    result = Dense(
        1, activation="sigmoid", kernel_initializer="lecun_uniform", name="interaction"
    )

    output = result(predict_layer)

    model = Model(
        inputs=[user, item],
        outputs=[output],
    )

    return model

# %% [markdown]
# ### Parameters

# %%
num_epochs = 20
learning_rate = 0.001
batch_size = 128
val_split = 0.1
latent_dim_mf = 16
latent_dim_mlp = 4
dense_layers = [8,8]
reg_layers = [0.01, 0.01]
activation_dense = "relu"
reg_mf: int = 0
reg_mlp: int = 0.01

# %%
from tensorflow.keras.optimizers import Adam

ncf_model_movies = create_ncf_movies(
    n_users,
    n_items,
    latent_dim_mf,
    latent_dim_mlp,
    reg_mf,
    reg_mlp,
    dense_layers,
    reg_layers,
    activation_dense
)

ncf_model_movies.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss='mean_squared_error',
    metrics=[
        tf.keras.metrics.TruePositives(name="tp"),
        tf.keras.metrics.FalsePositives(name="fp"),
        tf.keras.metrics.TrueNegatives(name="tn"),
        tf.keras.metrics.FalseNegatives(name="fn"),
        tf.keras.metrics.BinaryAccuracy(name="accuracy"),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
        tf.keras.metrics.AUC(name="auc"),
    ],
)
ncf_model_movies._name = "neural_collaborative_filtering"
ncf_model_movies.summary()
# Out:
# Model: "neural_collaborative_filtering"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  userId (InputLayer)            [(None,)]            0           []
#
#  movieId (InputLayer)           [(None,)]            0           []
#
#  mlp_user_embedding (Embedding)  (None, 4)           2684        ['userId[0][0]']
#
#  mlp_item_embedding (Embedding)  (None, 4)           3188        ['movieId[0][0]']
#
#  flatten_10 (Flatten)           (None, 4)            0           ['mlp_user_embedding[0][0]']
#
#  flatten_11 (Flatten)           (None, 4)            0           ['mlp_item_embedding[0][0]']
#
#  mf_user_embedding (Embedding)  (None, 16)           10736       ['userId[0][0]']
#
#  mf_item_embedding (Embedding)  (None, 16)           12752       ['movieId[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 8)            0           ['flatten_10[0][0]',
#                                                                   'flatten_11[0][0]']
#
#  flatten_8 (Flatten)            (None, 16)           0           ['mf_user_embedding[0][0]']
#
#  flatten_9 (Flatten)            (None, 16)           0           ['mf_item_embedding[0][0]']
#
#  layer0 (Dense)                 (None, 8)            72          ['concatenate_4[0][0]']
#
#  multiply_2 (Multiply)          (None, 16)           0           ['flatten_8[0][0]',
#                                                                   'flatten_9[0][0]']
#
#  layer1 (Dense)                 (None, 8)            72          ['layer0[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 24)           0           ['multiply_2[0][0]',
#                                                                   'layer1[0][0]']
#
#  interaction (Dense)            (None, 1)            25          ['concatenate_5[0][0]']
#
# ==================================================================================================
# Total params: 29,529
# Trainable params: 29,529
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def make_tf_dataset(data: pd.DataFrame, target: str, batch_size: int = 128, val_split: float = 0.2):
    # Convert the DataFrame to TensorFlow dataset
    dataset = tf.data.Dataset.from_tensor_slices(({
        'userId': data['userId'].values,
        'movieId': data['movieId'].values
    }, data[target].values))
    
    # Shuffle and split the dataset
    dataset = dataset.shuffle(buffer_size=len(data))
    train_size = int((1 - val_split) * len(data))
    
    train_dataset = dataset.take(train_size)
    val_dataset = dataset.skip(train_size)
    
    # Batch the datasets
    train_dataset = train_dataset.batch(batch_size)
    val_dataset = val_dataset.batch(batch_size)
    
    return train_dataset, val_dataset

m_train, m_val = make_tf_dataset(ratings, ["rating"], batch_size, val_split)

# %%
num_elements = tf.data.experimental.cardinality(m_train).numpy()
print(f"Liczba elementów w ds_train: {num_elements}")
num_elements_val = tf.data.experimental.cardinality(m_val).numpy()
print(f"Liczba elementów w ds_val: {num_elements_val}")
# Out:
# Liczba elementów w ds_train: 3761
# Liczba elementów w ds_val: 418

# %%
# define logs and callbacks
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=2
)

train_hist = ncf_model_movies.fit(
    m_train,
    validation_data=m_val,
    epochs=num_epochs,
    callbacks=[tensorboard_callback, early_stopping_callback],
    verbose=1,
)

ncf_evaluation = ncf_model_movies.evaluate(m_val)
print(f'Neural Collaborative Filtering Model Evaluation: {ncf_evaluation}')
# Out:
# Epoch 1/20
# 3761/3761 [==============================] - 9s 2ms/step - loss: 0.0765 - tp: 563.0000 - fp: 450.0000 - tn: 445820.0000 - fn: 34475.0000 - accuracy: 0.9274 - precision: 0.5558 - recall: 0.0161 - auc: 0.7343 - val_loss: 0.0535 - val_tp: 388.0000 - val_fp: 148.0000 - val_tn: 49547.0000 - val_fn: 3396.0000 - val_accuracy: 0.9337 - val_precision: 0.7239 - val_recall: 0.1025 - val_auc: 0.8539
# Epoch 2/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0514 - tp: 7034.0000 - fp: 3344.0000 - tn: 443003.0000 - fn: 27927.0000 - accuracy: 0.9350 - precision: 0.6778 - recall: 0.2012 - auc: 0.8685 - val_loss: 0.0478 - val_tp: 1007.0000 - val_fp: 373.0000 - val_tn: 49217.0000 - val_fn: 2882.0000 - val_accuracy: 0.9391 - val_precision: 0.7297 - val_recall: 0.2589 - val_auc: 0.8893
# Epoch 3/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0474 - tp: 9995.0000 - fp: 4188.0000 - tn: 442005.0000 - fn: 25120.0000 - accuracy: 0.9391 - precision: 0.7047 - recall: 0.2846 - auc: 0.8906 - val_loss: 0.0456 - val_tp: 1239.0000 - val_fp: 429.0000 - val_tn: 49103.0000 - val_fn: 2708.0000 - val_accuracy: 0.9413 - val_precision: 0.7428 - val_recall: 0.3139 - val_auc: 0.8982
# Epoch 4/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0451 - tp: 11710.0000 - fp: 4504.0000 - tn: 441666.0000 - fn: 23428.0000 - accuracy: 0.9420 - precision: 0.7222 - recall: 0.3333 - auc: 0.9023 - val_loss: 0.0425 - val_tp: 1482.0000 - val_fp: 419.0000 - val_tn: 49097.0000 - val_fn: 2481.0000 - val_accuracy: 0.9458 - val_precision: 0.7796 - val_recall: 0.3740 - val_auc: 0.9120
# Epoch 5/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0433 - tp: 12942.0000 - fp: 4611.0000 - tn: 441641.0000 - fn: 22114.0000 - accuracy: 0.9445 - precision: 0.7373 - recall: 0.3692 - auc: 0.9091 - val_loss: 0.0413 - val_tp: 1531.0000 - val_fp: 420.0000 - val_tn: 49164.0000 - val_fn: 2364.0000 - val_accuracy: 0.9479 - val_precision: 0.7847 - val_recall: 0.3931 - val_auc: 0.9125
# Epoch 6/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0418 - tp: 14068.0000 - fp: 4735.0000 - tn: 441522.0000 - fn: 20983.0000 - accuracy: 0.9466 - precision: 0.7482 - recall: 0.4014 - auc: 0.9142 - val_loss: 0.0382 - val_tp: 1697.0000 - val_fp: 476.0000 - val_tn: 49180.0000 - val_fn: 2126.0000 - val_accuracy: 0.9513 - val_precision: 0.7809 - val_recall: 0.4439 - val_auc: 0.9252
# Epoch 7/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0406 - tp: 14977.0000 - fp: 4830.0000 - tn: 441374.0000 - fn: 20127.0000 - accuracy: 0.9481 - precision: 0.7561 - recall: 0.4266 - auc: 0.9176 - val_loss: 0.0379 - val_tp: 1847.0000 - val_fp: 435.0000 - val_tn: 49144.0000 - val_fn: 2053.0000 - val_accuracy: 0.9535 - val_precision: 0.8094 - val_recall: 0.4736 - val_auc: 0.9239
# Epoch 8/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0396 - tp: 15649.0000 - fp: 4794.0000 - tn: 441502.0000 - fn: 19363.0000 - accuracy: 0.9498 - precision: 0.7655 - recall: 0.4470 - auc: 0.9197 - val_loss: 0.0368 - val_tp: 1872.0000 - val_fp: 445.0000 - val_tn: 49133.0000 - val_fn: 2029.0000 - val_accuracy: 0.9537 - val_precision: 0.8079 - val_recall: 0.4799 - val_auc: 0.9259
# Epoch 9/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0388 - tp: 16323.0000 - fp: 4861.0000 - tn: 441363.0000 - fn: 18761.0000 - accuracy: 0.9509 - precision: 0.7705 - recall: 0.4653 - auc: 0.9206 - val_loss: 0.0367 - val_tp: 1950.0000 - val_fp: 461.0000 - val_tn: 49090.0000 - val_fn: 1978.0000 - val_accuracy: 0.9544 - val_precision: 0.8088 - val_recall: 0.4964 - val_auc: 0.9255
# Epoch 10/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0381 - tp: 16956.0000 - fp: 4827.0000 - tn: 441444.0000 - fn: 18081.0000 - accuracy: 0.9524 - precision: 0.7784 - recall: 0.4839 - auc: 0.9214 - val_loss: 0.0353 - val_tp: 1939.0000 - val_fp: 396.0000 - val_tn: 49172.0000 - val_fn: 1972.0000 - val_accuracy: 0.9557 - val_precision: 0.8304 - val_recall: 0.4958 - val_auc: 0.9266
# Epoch 11/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0377 - tp: 17282.0000 - fp: 4814.0000 - tn: 441392.0000 - fn: 17820.0000 - accuracy: 0.9530 - precision: 0.7821 - recall: 0.4923 - auc: 0.9214 - val_loss: 0.0350 - val_tp: 2086.0000 - val_fp: 437.0000 - val_tn: 49114.0000 - val_fn: 1842.0000 - val_accuracy: 0.9574 - val_precision: 0.8268 - val_recall: 0.5311 - val_auc: 0.9254
# Epoch 12/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0371 - tp: 17533.0000 - fp: 4819.0000 - tn: 441533.0000 - fn: 17423.0000 - accuracy: 0.9538 - precision: 0.7844 - recall: 0.5016 - auc: 0.9215 - val_loss: 0.0349 - val_tp: 2119.0000 - val_fp: 417.0000 - val_tn: 49126.0000 - val_fn: 1817.0000 - val_accuracy: 0.9582 - val_precision: 0.8356 - val_recall: 0.5384 - val_auc: 0.9236
# Epoch 13/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0369 - tp: 18135.0000 - fp: 4801.0000 - tn: 441246.0000 - fn: 17126.0000 - accuracy: 0.9544 - precision: 0.7907 - recall: 0.5143 - auc: 0.9211 - val_loss: 0.0342 - val_tp: 2106.0000 - val_fp: 452.0000 - val_tn: 49159.0000 - val_fn: 1762.0000 - val_accuracy: 0.9586 - val_precision: 0.8233 - val_recall: 0.5445 - val_auc: 0.9260
# Epoch 14/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0363 - tp: 18246.0000 - fp: 4759.0000 - tn: 441527.0000 - fn: 16776.0000 - accuracy: 0.9553 - precision: 0.7931 - recall: 0.5210 - auc: 0.9211 - val_loss: 0.0346 - val_tp: 2118.0000 - val_fp: 426.0000 - val_tn: 49160.0000 - val_fn: 1775.0000 - val_accuracy: 0.9588 - val_precision: 0.8325 - val_recall: 0.5441 - val_auc: 0.9181
# Epoch 15/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0362 - tp: 18509.0000 - fp: 4845.0000 - tn: 441383.0000 - fn: 16571.0000 - accuracy: 0.9555 - precision: 0.7925 - recall: 0.5276 - auc: 0.9193 - val_loss: 0.0338 - val_tp: 2224.0000 - val_fp: 442.0000 - val_tn: 49106.0000 - val_fn: 1707.0000 - val_accuracy: 0.9598 - val_precision: 0.8342 - val_recall: 0.5658 - val_auc: 0.9246
# Epoch 16/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0358 - tp: 18713.0000 - fp: 4729.0000 - tn: 441571.0000 - fn: 16295.0000 - accuracy: 0.9563 - precision: 0.7983 - recall: 0.5345 - auc: 0.9185 - val_loss: 0.0330 - val_tp: 2241.0000 - val_fp: 416.0000 - val_tn: 49131.0000 - val_fn: 1691.0000 - val_accuracy: 0.9606 - val_precision: 0.8434 - val_recall: 0.5699 - val_auc: 0.9252
# Epoch 17/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0356 - tp: 18932.0000 - fp: 4732.0000 - tn: 441535.0000 - fn: 16109.0000 - accuracy: 0.9567 - precision: 0.8000 - recall: 0.5403 - auc: 0.9175 - val_loss: 0.0336 - val_tp: 2330.0000 - val_fp: 416.0000 - val_tn: 49042.0000 - val_fn: 1691.0000 - val_accuracy: 0.9606 - val_precision: 0.8485 - val_recall: 0.5795 - val_auc: 0.9234
# Epoch 18/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0353 - tp: 19255.0000 - fp: 4696.0000 - tn: 441527.0000 - fn: 15830.0000 - accuracy: 0.9574 - precision: 0.8039 - recall: 0.5488 - auc: 0.9162 - val_loss: 0.0322 - val_tp: 2211.0000 - val_fp: 414.0000 - val_tn: 49244.0000 - val_fn: 1610.0000 - val_accuracy: 0.9622 - val_precision: 0.8423 - val_recall: 0.5786 - val_auc: 0.9211
# Epoch 19/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0351 - tp: 19366.0000 - fp: 4691.0000 - tn: 441523.0000 - fn: 15728.0000 - accuracy: 0.9576 - precision: 0.8050 - recall: 0.5518 - auc: 0.9151 - val_loss: 0.0316 - val_tp: 2236.0000 - val_fp: 404.0000 - val_tn: 49261.0000 - val_fn: 1578.0000 - val_accuracy: 0.9629 - val_precision: 0.8470 - val_recall: 0.5863 - val_auc: 0.9182
# Epoch 20/20
# 3761/3761 [==============================] - 8s 2ms/step - loss: 0.0348 - tp: 19605.0000 - fp: 4642.0000 - tn: 441549.0000 - fn: 15512.0000 - accuracy: 0.9581 - precision: 0.8086 - recall: 0.5583 - auc: 0.9144 - val_loss: 0.0322 - val_tp: 2319.0000 - val_fp: 431.0000 - val_tn: 49158.0000 - val_fn: 1571.0000 - val_accuracy: 0.9626 - val_precision: 0.8433 - val_recall: 0.5961 - val_auc: 0.9157
# 418/418 [==============================] - 2s 1ms/step - loss: 0.0325 - tp: 2251.0000 - fp: 390.0000 - tn: 49218.0000 - fn: 1620.0000 - accuracy: 0.9624 - precision: 0.8523 - recall: 0.5815 - auc: 0.9141
# Neural Collaborative Filtering Model Evaluation: [0.03246220201253891, 2251.0, 390.0, 49218.0, 1620.0, 0.9624151587486267, 0.8523286581039429, 0.5815035104751587, 0.9140697717666626]

# %%
import os.path

ncf_model_movies.save('models/NeuMF_model.h5')
print('saved')
# Out:
# saved
